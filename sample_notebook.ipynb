# %% [markdown]
# # Sample Notebook
#
# This is a test notebook to verify PDF export functionality.

# %%
# Import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Analysis Example
#
# Let's create some sample data and analyze it.

# %%
# Create sample data
data = {
    'Product': ['Bond A', 'Bond B', 'Bond C', 'Bond D'],
    'Yield': [2.5, 3.1, 2.8, 3.4],
    'Price': [98.5, 102.3, 99.8, 101.5]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Product  Yield  Price
# 0  Bond A    2.5   98.5
# 1  Bond B    3.1  102.3
# 2  Bond C    2.8   99.8
# 3  Bond D    3.4  101.5

# %%
# Calculate statistics
print(f"Average Yield: {df['Yield'].mean():.2f}%")
print(f"Average Price: {df['Price'].mean():.2f}")
# Out:
# Average Yield: 2.95%
# Average Price: 100.53

# %%
x=4

# %%
# Loaded variable 'df' from URI: c:\Users\Eddy\YTM Capital Dropbox\Eddy Winiarz\Trading\COF\Models\Unfinished Models\Eddy\Python Projects\Bond-RV-App\analytics\processed_data\cad_cheap_vs_usd.csv
import pandas as pd
df = pd.read_csv(r'c:\Users\Eddy\YTM Capital Dropbox\Eddy Winiarz\Trading\COF\Models\Unfinished Models\Eddy\Python Projects\Bond-RV-App\analytics\processed_data\cad_cheap_vs_usd.csv')

# %%
df
# Out:
#                   Bond_1              Bond_2        Last         Avg  \
# 0    ENBCN 5.36 05/26/33  ENBCN 7.2 06/27/54 -111.838027 -132.978818
# 1    ENBCN 4.56 02/25/35  ENBCN 7.2 06/27/54 -100.393974 -121.557397
# 2    ENBCN 4.73 08/22/34  ENBCN 7.2 06/27/54 -103.454973 -124.290950
# 3     ENBCN 6.1 11/09/32  ENBCN 7.2 06/27/54 -115.802074 -135.418367
# 4     ENBCN 3.1 09/21/33  ENBCN 7.2 06/27/54 -125.723860 -142.936718
# ..                   ...                 ...         ...         ...
# 427      TCN 5  11/15/32    TCN 3.4 05/13/32   -2.816253   16.994239
# 428    TCN 4.95 02/18/31    TCN 3.4 05/13/32  -17.205542    4.385454
# 429    TCN 4.65 08/13/31    TCN 3.4 05/13/32  -14.950670    7.457723
# 430    TCN 4.95 03/28/33    TCN 3.4 05/13/32    0.448130   20.412994
# 431    TCN 2.85 11/13/31    TCN 3.4 05/13/32  -32.043658   -9.266785
#
#         vs Avg   Z Score  Percentile    cusip_1    cusip_2
# 0    21.140791  1.422969   85.405405  29251ZBZ9  29250NCF0
# ...

# %%
# Load runs adjusted timeseries data
import pandas as pd

# Load from analytics/processed_data directory
df_runs = pd.read_csv('analytics/processed_data/runs_today.csv')

# Display basic info
df_runs.head()
# Out:
#        CUSIP              Security  Bid Workout Risk  Tight Bid >3mm  \
# 0  00206RDY5       T 4.85 05/25/47           12.7900           144.0
# 1  00206RGB2          T 4 11/25/25               NaN            53.0
# 2  00206RGC0        T 5.1 11/25/48           13.4125           144.0
# 3  00208DAA9  ARXCN 2.354 03/10/26            0.3300            48.0
# 4  00208DAB7  ARXCN 3.465 03/10/31            4.7425           103.0
#
#    Wide Offer >3mm  Bid/Offer>3mm  Tight Bid  Wide Offer  Bid/Offer  \
# 0            143.0            1.0      144.0       145.0       -1.0
# 1              NaN            NaN       53.0        48.0        5.0
# 2            143.0            1.0      144.0       145.0       -1.0
# 3              NaN            NaN       48.0        49.0       -1.0
# 4            100.0            3.0      103.0       100.0        3.0
#
#   Dealer @ Tight Bid >3mm  ... 1yr Chg CR01 @ Tight Bid  \
# 0                     NBF  ...                   263.75
# ...
